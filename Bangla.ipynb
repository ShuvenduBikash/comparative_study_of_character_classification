# %%
from keras import models, layers, losses, optimizers, metrics
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
train_dir = 'E:\\Datasets\\Bangla\\train'
test_dir = 'E:\\Datasets\\Bangla\\test'

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir, 
    target_size=(28, 28), 
    batch_size=32
)

test_generator = test_datagen.flow_from_directory(
    test_dir, 
    target_size=(28, 28), 
    batch_size=32
)
# Out:
# Found 4000 images belonging to 10 classes.
# Found 2000 images belonging to 10 classes.

# %%
for data_batch, label_batch in train_generator:
    print(data_batch.shape)
    print(label_batch.shape)
    break
# Out:
# (32, 28, 28, 3)
# (32, 10)

# %%
def plot_images(images, cls_true, cls_pred=None):
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(images[i], cmap='binary')

        # Show true and predicted classes.
        if cls_pred is None:
            xlabel = "True: {0}".format(cls_true[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])

        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %%
plot_images(data_batch[:9], np.argmax(label_batch[:9], axis=1))

# %% [markdown]
# # Deep neural network

# %%
model = models.Sequential()

model.add(layers.Flatten(input_shape=(28, 28, 3)))
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 2352)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2409472
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 2,419,722
# Trainable params: 2,419,722
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(
    optimizer=optimizers.RMSprop(lr=1e-4), 
    loss=losses.categorical_crossentropy, 
    metrics=[metrics.categorical_accuracy]
)

history = model.fit_generator(train_generator, 
                              steps_per_epoch=125, 
                              epochs=30, 
                              validation_data=test_generator, 
                              validation_steps=65)
# Out:
# Epoch 1/30
# 125/125 [==============================] - 3s 21ms/step - loss: 0.8202 - categorical_accuracy: 0.7458 - val_loss: 0.4276 - val_categorical_accuracy: 0.8609
# Epoch 2/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3950 - categorical_accuracy: 0.8728 - val_loss: 0.4000 - val_categorical_accuracy: 0.8609
# Epoch 3/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2931 - categorical_accuracy: 0.9038 - val_loss: 0.3629 - val_categorical_accuracy: 0.8900
# Epoch 4/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2490 - categorical_accuracy: 0.9188 - val_loss: 0.3668 - val_categorical_accuracy: 0.8861
# Epoch 5/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1968 - categorical_accuracy: 0.9355 - val_loss: 0.3943 - val_categorical_accuracy: 0.8706
# Epoch 6/30
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1722 - categorical_accuracy: 0.9433 - val_loss: 0.3963 - val_categorical_accuracy: 0.8571
# Epoch 7/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1420 - categorical_accuracy: 0.9550 - val_loss: 0.2838 - val_categorical_accuracy: 0.9075
# Epoch 8/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1153 - categorical_accuracy: 0.9655 - val_loss: 0.2829 - val_categorical_accuracy: 0.9094
# Epoch 9/30
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1003 - categorical_accuracy: 0.9665 - val_loss: 0.3477 - val_categorical_accuracy: 0.8924
# Epoch 10/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0853 - categorical_accuracy: 0.9742 - val_loss: 0.2865 - val_categorical_accuracy: 0.9099
# Epoch 11/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0746 - categorical_accuracy: 0.9778 - val_loss: 0.3344 - val_categorical_accuracy: 0.9055
# Epoch 12/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0621 - categorical_accuracy: 0.9818 - val_loss: 0.3655 - val_categorical_accuracy: 0.8803
# Epoch 13/30
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0553 - categorical_accuracy: 0.9855 - val_loss: 0.3556 - val_categorical_accuracy: 0.8944
# Epoch 14/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0367 - categorical_accuracy: 0.9912 - val_loss: 0.4280 - val_categorical_accuracy: 0.8726
# Epoch 15/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0401 - categorical_accuracy: 0.9882 - val_loss: 0.3632 - val_categorical_accuracy: 0.8944
# Epoch 16/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0315 - categorical_accuracy: 0.9908 - val_loss: 0.2903 - val_categorical_accuracy: 0.9186
# Epoch 17/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0284 - categorical_accuracy: 0.9912 - val_loss: 0.2817 - val_categorical_accuracy: 0.9244
# Epoch 18/30
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0238 - categorical_accuracy: 0.9938 - val_loss: 0.2865 - val_categorical_accuracy: 0.9196
# Epoch 19/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0189 - categorical_accuracy: 0.9950 - val_loss: 0.2864 - val_categorical_accuracy: 0.9225
# Epoch 20/30
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0179 - categorical_accuracy: 0.9955 - val_loss: 0.2867 - val_categorical_accuracy: 0.9230
# Epoch 21/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0138 - categorical_accuracy: 0.9975 - val_loss: 0.2940 - val_categorical_accuracy: 0.9210
# Epoch 22/30
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0140 - categorical_accuracy: 0.9965 - val_loss: 0.3503 - val_categorical_accuracy: 0.9055
# Epoch 23/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0111 - categorical_accuracy: 0.9975 - val_loss: 0.4158 - val_categorical_accuracy: 0.8895
# Epoch 24/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0091 - categorical_accuracy: 0.9980 - val_loss: 0.3511 - val_categorical_accuracy: 0.9167
# Epoch 25/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0091 - categorical_accuracy: 0.9982 - val_loss: 0.3417 - val_categorical_accuracy: 0.9152
# Epoch 26/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0074 - categorical_accuracy: 0.9982 - val_loss: 0.3014 - val_categorical_accuracy: 0.9273
# Epoch 27/30
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0072 - categorical_accuracy: 0.9985 - val_loss: 0.3061 - val_categorical_accuracy: 0.9283
# Epoch 28/30
# 125/125 [==============================] - 1s 10ms/step - loss: 0.0060 - categorical_accuracy: 0.9988 - val_loss: 0.3391 - val_categorical_accuracy: 0.9210
# Epoch 29/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0057 - categorical_accuracy: 0.9985 - val_loss: 0.3390 - val_categorical_accuracy: 0.9196
# Epoch 30/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0042 - categorical_accuracy: 0.9993 - val_loss: 0.3278 - val_categorical_accuracy: 0.9230

# %%
import matplotlib.pyplot as plt

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label='Training losses')
plt.plot(epochs, val_loss, 'b', label='Validation losses')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # Convolutional neural network

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 3)))
model.add(layers.MaxPool2D(2, 2))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPool2D(2, 2))


model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               819712
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 844,234
# Trainable params: 844,234
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(
    optimizer=optimizers.RMSprop(lr=1e-4), 
    loss=losses.categorical_crossentropy, 
    metrics=[metrics.categorical_accuracy]
)

# %%
history = model.fit_generator(train_generator, 
                              steps_per_epoch=125, 
                              epochs=30, 
                              validation_data=test_generator, 
                              validation_steps=65)
# Out:
# Epoch 1/30
# 125/125 [==============================] - 2s 17ms/step - loss: 1.5235 - categorical_accuracy: 0.6148 - val_loss: 0.8291 - val_categorical_accuracy: 0.7859
# Epoch 2/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5885 - categorical_accuracy: 0.8360 - val_loss: 0.4980 - val_categorical_accuracy: 0.8440
# Epoch 3/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3944 - categorical_accuracy: 0.8820 - val_loss: 0.4331 - val_categorical_accuracy: 0.8425
# Epoch 4/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3070 - categorical_accuracy: 0.9080 - val_loss: 0.3424 - val_categorical_accuracy: 0.8847
# Epoch 5/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2503 - categorical_accuracy: 0.9188 - val_loss: 0.2721 - val_categorical_accuracy: 0.9079
# Epoch 6/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2036 - categorical_accuracy: 0.9373 - val_loss: 0.2745 - val_categorical_accuracy: 0.9075
# Epoch 7/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1706 - categorical_accuracy: 0.9477 - val_loss: 0.2465 - val_categorical_accuracy: 0.9201
# Epoch 8/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1490 - categorical_accuracy: 0.9555 - val_loss: 0.2187 - val_categorical_accuracy: 0.9293
# Epoch 9/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1258 - categorical_accuracy: 0.9620 - val_loss: 0.1882 - val_categorical_accuracy: 0.9365
# Epoch 10/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1075 - categorical_accuracy: 0.9670 - val_loss: 0.2357 - val_categorical_accuracy: 0.9249
# Epoch 11/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0948 - categorical_accuracy: 0.9715 - val_loss: 0.2002 - val_categorical_accuracy: 0.9302
# Epoch 12/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0837 - categorical_accuracy: 0.9758 - val_loss: 0.1871 - val_categorical_accuracy: 0.9375
# Epoch 13/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0718 - categorical_accuracy: 0.9788 - val_loss: 0.1906 - val_categorical_accuracy: 0.9423
# Epoch 14/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0620 - categorical_accuracy: 0.9838 - val_loss: 0.1964 - val_categorical_accuracy: 0.9356
# Epoch 15/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0553 - categorical_accuracy: 0.9850 - val_loss: 0.1834 - val_categorical_accuracy: 0.9404
# Epoch 16/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0488 - categorical_accuracy: 0.9855 - val_loss: 0.1702 - val_categorical_accuracy: 0.9419
# Epoch 17/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0418 - categorical_accuracy: 0.9885 - val_loss: 0.1746 - val_categorical_accuracy: 0.9370
# Epoch 18/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0365 - categorical_accuracy: 0.9895 - val_loss: 0.2167 - val_categorical_accuracy: 0.9278
# Epoch 19/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0302 - categorical_accuracy: 0.9938 - val_loss: 0.1795 - val_categorical_accuracy: 0.9453
# Epoch 20/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0262 - categorical_accuracy: 0.9942 - val_loss: 0.1873 - val_categorical_accuracy: 0.9457
# Epoch 21/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0242 - categorical_accuracy: 0.9942 - val_loss: 0.1716 - val_categorical_accuracy: 0.9477
# Epoch 22/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0198 - categorical_accuracy: 0.9958 - val_loss: 0.1804 - val_categorical_accuracy: 0.9419
# Epoch 23/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0178 - categorical_accuracy: 0.9960 - val_loss: 0.1825 - val_categorical_accuracy: 0.9448
# Epoch 24/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0133 - categorical_accuracy: 0.9978 - val_loss: 0.1852 - val_categorical_accuracy: 0.9423
# Epoch 25/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0122 - categorical_accuracy: 0.9975 - val_loss: 0.1924 - val_categorical_accuracy: 0.9457
# Epoch 26/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0112 - categorical_accuracy: 0.9975 - val_loss: 0.2172 - val_categorical_accuracy: 0.9394
# Epoch 27/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0100 - categorical_accuracy: 0.9968 - val_loss: 0.1910 - val_categorical_accuracy: 0.9443
# Epoch 28/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0075 - categorical_accuracy: 0.9982 - val_loss: 0.2154 - val_categorical_accuracy: 0.9394
# Epoch 29/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0060 - categorical_accuracy: 0.9993 - val_loss: 0.1979 - val_categorical_accuracy: 0.9448
# Epoch 30/30
# 125/125 [==============================] - 1s 11ms/step - loss: 0.0050 - categorical_accuracy: 0.9993 - val_loss: 0.1971 - val_categorical_accuracy: 0.9438

# %%
import matplotlib.pyplot as plt

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label='Training losses')
plt.plot(epochs, val_loss, 'b', label='Validation losses')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # LSTM

# %%
model = models.Sequential()

model.add(layers.Reshape((28, 28*3), input_shape=(28, 28, 3)))
model.add(layers.LSTM(500, dropout=0.2, recurrent_dropout=0.2))
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 28, 84)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 500)               1170000
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 1,175,010
# Trainable params: 1,175,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=optimizers.RMSprop(lr=1e-4), 
    loss=losses.categorical_crossentropy, 
    metrics=[metrics.categorical_accuracy]
)

# %%
history = model.fit_generator(train_generator, 
                              steps_per_epoch=125, 
                              epochs=30, 
                              validation_data=test_generator, 
                              validation_steps=65)
# Out:
# Epoch 1/30
# 125/125 [==============================] - 5s 44ms/step - loss: 1.7717 - categorical_accuracy: 0.4113 - val_loss: 1.0856 - val_categorical_accuracy: 0.6628
# Epoch 2/30
# 125/125 [==============================] - 5s 39ms/step - loss: 1.0821 - categorical_accuracy: 0.6545 - val_loss: 0.7072 - val_categorical_accuracy: 0.7670
# Epoch 3/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.8132 - categorical_accuracy: 0.7420 - val_loss: 0.5463 - val_categorical_accuracy: 0.8222
# Epoch 4/30
# 125/125 [==============================] - 5s 39ms/step - loss: 0.6351 - categorical_accuracy: 0.7920 - val_loss: 0.4532 - val_categorical_accuracy: 0.8513
# Epoch 5/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.5576 - categorical_accuracy: 0.8210 - val_loss: 0.4037 - val_categorical_accuracy: 0.8735
# Epoch 6/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.4885 - categorical_accuracy: 0.8417 - val_loss: 0.3533 - val_categorical_accuracy: 0.8842
# Epoch 7/30
# 125/125 [==============================] - 5s 38ms/step - loss: 0.4453 - categorical_accuracy: 0.8540 - val_loss: 0.3009 - val_categorical_accuracy: 0.9060
# Epoch 8/30
# 125/125 [==============================] - 5s 39ms/step - loss: 0.3720 - categorical_accuracy: 0.8792 - val_loss: 0.2896 - val_categorical_accuracy: 0.9060
# Epoch 9/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.3437 - categorical_accuracy: 0.8842 - val_loss: 0.2658 - val_categorical_accuracy: 0.9181
# Epoch 10/30
# 125/125 [==============================] - 5s 38ms/step - loss: 0.3109 - categorical_accuracy: 0.8997 - val_loss: 0.2816 - val_categorical_accuracy: 0.9147
# Epoch 11/30
# 125/125 [==============================] - 5s 38ms/step - loss: 0.2894 - categorical_accuracy: 0.8995 - val_loss: 0.2587 - val_categorical_accuracy: 0.9128
# Epoch 12/30
# 125/125 [==============================] - 5s 39ms/step - loss: 0.2726 - categorical_accuracy: 0.9065 - val_loss: 0.2449 - val_categorical_accuracy: 0.9239
# Epoch 13/30
# 125/125 [==============================] - 5s 39ms/step - loss: 0.2544 - categorical_accuracy: 0.9155 - val_loss: 0.2199 - val_categorical_accuracy: 0.9273
# Epoch 14/30
# 125/125 [==============================] - 5s 39ms/step - loss: 0.2324 - categorical_accuracy: 0.9225 - val_loss: 0.1999 - val_categorical_accuracy: 0.9409
# Epoch 15/30
# 125/125 [==============================] - 5s 39ms/step - loss: 0.2197 - categorical_accuracy: 0.9223 - val_loss: 0.2103 - val_categorical_accuracy: 0.9327
# Epoch 16/30
# 125/125 [==============================] - 5s 39ms/step - loss: 0.2032 - categorical_accuracy: 0.9355 - val_loss: 0.2064 - val_categorical_accuracy: 0.9312
# Epoch 17/30
# 125/125 [==============================] - 5s 39ms/step - loss: 0.1905 - categorical_accuracy: 0.9363 - val_loss: 0.1927 - val_categorical_accuracy: 0.9390
# Epoch 18/30
# 125/125 [==============================] - 5s 38ms/step - loss: 0.1727 - categorical_accuracy: 0.9410 - val_loss: 0.1957 - val_categorical_accuracy: 0.9327
# Epoch 19/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.1717 - categorical_accuracy: 0.9425 - val_loss: 0.1842 - val_categorical_accuracy: 0.9385
# Epoch 20/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.1686 - categorical_accuracy: 0.9440 - val_loss: 0.2115 - val_categorical_accuracy: 0.9341
# Epoch 21/30
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1543 - categorical_accuracy: 0.9467 - val_loss: 0.1569 - val_categorical_accuracy: 0.9443
# Epoch 22/30
# 125/125 [==============================] - 5s 41ms/step - loss: 0.1478 - categorical_accuracy: 0.9500 - val_loss: 0.1830 - val_categorical_accuracy: 0.9414
# Epoch 23/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.1471 - categorical_accuracy: 0.9513 - val_loss: 0.1544 - val_categorical_accuracy: 0.9438
# Epoch 24/30
# 125/125 [==============================] - 5s 39ms/step - loss: 0.1304 - categorical_accuracy: 0.9562 - val_loss: 0.1757 - val_categorical_accuracy: 0.9414
# Epoch 25/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.1210 - categorical_accuracy: 0.9605 - val_loss: 0.1598 - val_categorical_accuracy: 0.9428
# Epoch 26/30
# 125/125 [==============================] - 5s 39ms/step - loss: 0.1142 - categorical_accuracy: 0.9637 - val_loss: 0.1563 - val_categorical_accuracy: 0.9491
# Epoch 27/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.1114 - categorical_accuracy: 0.9622 - val_loss: 0.1513 - val_categorical_accuracy: 0.9486
# Epoch 28/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.1096 - categorical_accuracy: 0.9652 - val_loss: 0.1523 - val_categorical_accuracy: 0.9501
# Epoch 29/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.1070 - categorical_accuracy: 0.9680 - val_loss: 0.1541 - val_categorical_accuracy: 0.9491
# Epoch 30/30
# 125/125 [==============================] - 5s 41ms/step - loss: 0.0914 - categorical_accuracy: 0.9720 - val_loss: 0.1471 - val_categorical_accuracy: 0.9506

# %%
import matplotlib.pyplot as plt

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label='Training losses')
plt.plot(epochs, val_loss, 'b', label='Validation losses')
plt.title('Training and validation loss')
plt.legend()

plt.show()
