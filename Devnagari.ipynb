# %%
from keras import models, layers, losses, optimizers, metrics
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
train_dir = 'E:\\Datasets\\Devnagari\\train'
test_dir = 'E:\\Datasets\\Devnagari\\test'

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir, 
    target_size=(28, 28), 
    batch_size=32
)

test_generator = test_datagen.flow_from_directory(
    test_dir, 
    target_size=(28, 28), 
    batch_size=32
)
# Out:
# Found 2000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
for data_batch, label_batch in train_generator:
    print(data_batch.shape)
    print(label_batch.shape)
    break
# Out:
# (32, 28, 28, 3)
# (32, 10)

# %%
def plot_images(images, cls_true, cls_pred=None):
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(images[i], cmap='binary')

        # Show true and predicted classes.
        if cls_pred is None:
            xlabel = "True: {0}".format(cls_true[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])

        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %%
plot_images(data_batch[:9], np.argmax(label_batch[:9], axis=1))

# %% [markdown]
# # Deep neural network

# %%
model = models.Sequential()

model.add(layers.Flatten(input_shape=(28, 28, 3)))
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_4 (Flatten)          (None, 2352)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              2409472
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 2,419,722
# Trainable params: 2,419,722
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(
    optimizer=optimizers.RMSprop(lr=1e-4), 
    loss=losses.categorical_crossentropy, 
    metrics=[metrics.categorical_accuracy]
)

history = model.fit_generator(train_generator, 
                              steps_per_epoch=125, 
                              epochs=30, 
                              validation_data=test_generator, 
                              validation_steps=65)
# Out:
# Epoch 1/30
# 125/125 [==============================] - 2s 17ms/step - loss: 0.9887 - categorical_accuracy: 0.6895 - val_loss: 0.8315 - val_categorical_accuracy: 0.7338
# Epoch 2/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4380 - categorical_accuracy: 0.8602 - val_loss: 0.8014 - val_categorical_accuracy: 0.7416
# Epoch 3/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3155 - categorical_accuracy: 0.9018 - val_loss: 0.5975 - val_categorical_accuracy: 0.8243
# Epoch 4/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2273 - categorical_accuracy: 0.9302 - val_loss: 0.6257 - val_categorical_accuracy: 0.8081
# Epoch 5/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1734 - categorical_accuracy: 0.9495 - val_loss: 0.6224 - val_categorical_accuracy: 0.8282
# Epoch 6/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1299 - categorical_accuracy: 0.9652 - val_loss: 0.6278 - val_categorical_accuracy: 0.8312
# Epoch 7/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0993 - categorical_accuracy: 0.9735 - val_loss: 0.5921 - val_categorical_accuracy: 0.8396
# Epoch 8/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0774 - categorical_accuracy: 0.9800 - val_loss: 0.6408 - val_categorical_accuracy: 0.8366
# Epoch 9/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0532 - categorical_accuracy: 0.9882 - val_loss: 0.7192 - val_categorical_accuracy: 0.8233
# Epoch 10/30
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0447 - categorical_accuracy: 0.9915 - val_loss: 0.7335 - val_categorical_accuracy: 0.8263
# Epoch 11/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0356 - categorical_accuracy: 0.9930 - val_loss: 0.6934 - val_categorical_accuracy: 0.8391
# Epoch 12/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0292 - categorical_accuracy: 0.9930 - val_loss: 0.6716 - val_categorical_accuracy: 0.8455
# Epoch 13/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0233 - categorical_accuracy: 0.9945 - val_loss: 0.6643 - val_categorical_accuracy: 0.8474
# Epoch 14/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0195 - categorical_accuracy: 0.9957 - val_loss: 0.6475 - val_categorical_accuracy: 0.8430
# Epoch 15/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0157 - categorical_accuracy: 0.9965 - val_loss: 0.6750 - val_categorical_accuracy: 0.8583
# Epoch 16/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0125 - categorical_accuracy: 0.9980 - val_loss: 0.7105 - val_categorical_accuracy: 0.8479
# Epoch 17/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0148 - categorical_accuracy: 0.9955 - val_loss: 0.6773 - val_categorical_accuracy: 0.8558
# Epoch 18/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0118 - categorical_accuracy: 0.9977 - val_loss: 1.1031 - val_categorical_accuracy: 0.7697
# Epoch 19/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0107 - categorical_accuracy: 0.9957 - val_loss: 0.7208 - val_categorical_accuracy: 0.8460
# Epoch 20/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0108 - categorical_accuracy: 0.9972 - val_loss: 0.7112 - val_categorical_accuracy: 0.8617
# Epoch 21/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0070 - categorical_accuracy: 0.9990 - val_loss: 0.7577 - val_categorical_accuracy: 0.8632
# Epoch 22/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0124 - categorical_accuracy: 0.9955 - val_loss: 0.8030 - val_categorical_accuracy: 0.8430
# Epoch 23/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0084 - categorical_accuracy: 0.9980 - val_loss: 0.7497 - val_categorical_accuracy: 0.8543
# Epoch 24/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0065 - categorical_accuracy: 0.9987 - val_loss: 0.7738 - val_categorical_accuracy: 0.8548
# Epoch 25/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0070 - categorical_accuracy: 0.9982 - val_loss: 0.8246 - val_categorical_accuracy: 0.8450
# Epoch 26/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0096 - categorical_accuracy: 0.9975 - val_loss: 0.7874 - val_categorical_accuracy: 0.8597
# Epoch 27/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0067 - categorical_accuracy: 0.9980 - val_loss: 0.7738 - val_categorical_accuracy: 0.8593
# Epoch 28/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0060 - categorical_accuracy: 0.9987 - val_loss: 0.7889 - val_categorical_accuracy: 0.8568
# Epoch 29/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0078 - categorical_accuracy: 0.9982 - val_loss: 0.8697 - val_categorical_accuracy: 0.8425
# Epoch 30/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0041 - categorical_accuracy: 0.9987 - val_loss: 0.8128 - val_categorical_accuracy: 0.8524

# %%
import matplotlib.pyplot as plt

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label='Training losses')
plt.plot(epochs, val_loss, 'b', label='Validation losses')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # Convolutional neural network

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 3)))
model.add(layers.MaxPool2D(2, 2))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPool2D(2, 2))


model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 26, 26, 32)        896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               819712
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 844,234
# Trainable params: 844,234
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(
    optimizer=optimizers.RMSprop(lr=1e-4), 
    loss=losses.categorical_crossentropy, 
    metrics=[metrics.categorical_accuracy]
)

# %%
history = model.fit_generator(train_generator, 
                              steps_per_epoch=125, 
                              epochs=30, 
                              validation_data=test_generator, 
                              validation_steps=65)
# Out:
# Epoch 1/30
# 125/125 [==============================] - 2s 14ms/step - loss: 1.5657 - categorical_accuracy: 0.6143 - val_loss: 1.0628 - val_categorical_accuracy: 0.7195
# Epoch 2/30
# 125/125 [==============================] - 2s 12ms/step - loss: 0.7116 - categorical_accuracy: 0.7993 - val_loss: 0.7755 - val_categorical_accuracy: 0.7736
# Epoch 3/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4900 - categorical_accuracy: 0.8565 - val_loss: 0.6745 - val_categorical_accuracy: 0.7928
# Epoch 4/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3655 - categorical_accuracy: 0.8937 - val_loss: 0.5938 - val_categorical_accuracy: 0.8238
# Epoch 5/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.2867 - categorical_accuracy: 0.9248 - val_loss: 0.5900 - val_categorical_accuracy: 0.8322
# Epoch 6/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.2209 - categorical_accuracy: 0.9412 - val_loss: 0.5021 - val_categorical_accuracy: 0.8583
# Epoch 7/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1802 - categorical_accuracy: 0.9558 - val_loss: 0.4884 - val_categorical_accuracy: 0.8740
# Epoch 8/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1449 - categorical_accuracy: 0.9608 - val_loss: 0.4751 - val_categorical_accuracy: 0.8730
# Epoch 9/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1129 - categorical_accuracy: 0.9693 - val_loss: 0.4554 - val_categorical_accuracy: 0.8804
# Epoch 10/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0945 - categorical_accuracy: 0.9745 - val_loss: 0.4636 - val_categorical_accuracy: 0.8829
# Epoch 11/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0703 - categorical_accuracy: 0.9850 - val_loss: 0.4699 - val_categorical_accuracy: 0.8903
# Epoch 12/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0556 - categorical_accuracy: 0.9888 - val_loss: 0.4521 - val_categorical_accuracy: 0.8878
# Epoch 13/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0430 - categorical_accuracy: 0.9915 - val_loss: 0.4526 - val_categorical_accuracy: 0.8922
# Epoch 14/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0346 - categorical_accuracy: 0.9935 - val_loss: 0.4737 - val_categorical_accuracy: 0.8971
# Epoch 15/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0223 - categorical_accuracy: 0.9972 - val_loss: 0.4808 - val_categorical_accuracy: 0.8907
# Epoch 16/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0187 - categorical_accuracy: 0.9975 - val_loss: 0.4894 - val_categorical_accuracy: 0.8962
# Epoch 17/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0132 - categorical_accuracy: 0.9985 - val_loss: 0.5092 - val_categorical_accuracy: 0.8917
# Epoch 18/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0103 - categorical_accuracy: 0.9982 - val_loss: 0.4946 - val_categorical_accuracy: 0.8971
# Epoch 19/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0084 - categorical_accuracy: 0.9990 - val_loss: 0.5102 - val_categorical_accuracy: 0.9031
# Epoch 20/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0092 - categorical_accuracy: 0.9982 - val_loss: 0.5285 - val_categorical_accuracy: 0.8971
# Epoch 21/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0045 - categorical_accuracy: 0.9997 - val_loss: 0.5346 - val_categorical_accuracy: 0.9016
# Epoch 22/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0079 - categorical_accuracy: 0.9982 - val_loss: 0.5337 - val_categorical_accuracy: 0.9031
# Epoch 23/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0039 - categorical_accuracy: 0.9995 - val_loss: 0.5472 - val_categorical_accuracy: 0.9055
# Epoch 24/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0046 - categorical_accuracy: 0.9992 - val_loss: 0.5966 - val_categorical_accuracy: 0.8957
# Epoch 25/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0048 - categorical_accuracy: 0.9987 - val_loss: 0.5601 - val_categorical_accuracy: 0.9070
# Epoch 26/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0070 - categorical_accuracy: 0.9985 - val_loss: 0.5671 - val_categorical_accuracy: 0.9021
# Epoch 27/30
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0050 - categorical_accuracy: 0.9990 - val_loss: 0.6031 - val_categorical_accuracy: 0.8986
# Epoch 28/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0029 - categorical_accuracy: 0.9990 - val_loss: 0.5859 - val_categorical_accuracy: 0.9021
# Epoch 29/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0061 - categorical_accuracy: 0.9990 - val_loss: 0.6019 - val_categorical_accuracy: 0.9031
# Epoch 30/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0066 - categorical_accuracy: 0.9990 - val_loss: 0.6145 - val_categorical_accuracy: 0.8991

# %%
import matplotlib.pyplot as plt

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label='Training losses')
plt.plot(epochs, val_loss, 'b', label='Validation losses')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # LSTM

# %%
model = models.Sequential()

model.add(layers.Reshape((28, 28*3), input_shape=(28, 28, 3)))
model.add(layers.LSTM(500, dropout=0.2, recurrent_dropout=0.2))
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_3 (Reshape)          (None, 28, 84)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 500)               1170000
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                5010
# =================================================================
# Total params: 1,175,010
# Trainable params: 1,175,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=optimizers.RMSprop(lr=1e-4), 
    loss=losses.categorical_crossentropy, 
    metrics=[metrics.categorical_accuracy]
)

# %%
history = model.fit_generator(train_generator, 
                              steps_per_epoch=125, 
                              epochs=30, 
                              validation_data=test_generator, 
                              validation_steps=65)
# Out:
# Epoch 1/30
# 125/125 [==============================] - 7s 53ms/step - loss: 1.8056 - categorical_accuracy: 0.3690 - val_loss: 1.3640 - val_categorical_accuracy: 0.5261
# Epoch 2/30
# 125/125 [==============================] - 6s 48ms/step - loss: 1.1813 - categorical_accuracy: 0.5908 - val_loss: 1.1326 - val_categorical_accuracy: 0.5748
# Epoch 3/30
# 125/125 [==============================] - 6s 48ms/step - loss: 0.9653 - categorical_accuracy: 0.6688 - val_loss: 0.8767 - val_categorical_accuracy: 0.7018
# Epoch 4/30
# 125/125 [==============================] - 6s 46ms/step - loss: 0.8058 - categorical_accuracy: 0.7270 - val_loss: 0.8576 - val_categorical_accuracy: 0.6983
# Epoch 5/30
# 125/125 [==============================] - 6s 46ms/step - loss: 0.7010 - categorical_accuracy: 0.7647 - val_loss: 0.7254 - val_categorical_accuracy: 0.7559
# Epoch 6/30
# 125/125 [==============================] - 6s 45ms/step - loss: 0.6052 - categorical_accuracy: 0.7975 - val_loss: 0.6495 - val_categorical_accuracy: 0.8031
# Epoch 7/30
# 125/125 [==============================] - 6s 46ms/step - loss: 0.5242 - categorical_accuracy: 0.8192 - val_loss: 0.5933 - val_categorical_accuracy: 0.8066
# Epoch 8/30
# 125/125 [==============================] - 6s 47ms/step - loss: 0.4718 - categorical_accuracy: 0.8400 - val_loss: 0.5371 - val_categorical_accuracy: 0.8366
# Epoch 9/30
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4250 - categorical_accuracy: 0.8615 - val_loss: 0.4928 - val_categorical_accuracy: 0.8563
# Epoch 10/30
# 125/125 [==============================] - 6s 45ms/step - loss: 0.3566 - categorical_accuracy: 0.8860 - val_loss: 0.4901 - val_categorical_accuracy: 0.8479
# Epoch 11/30
# 125/125 [==============================] - 6s 47ms/step - loss: 0.3336 - categorical_accuracy: 0.8933 - val_loss: 0.4563 - val_categorical_accuracy: 0.8666
# Epoch 12/30
# 125/125 [==============================] - 6s 46ms/step - loss: 0.3145 - categorical_accuracy: 0.8985 - val_loss: 0.4453 - val_categorical_accuracy: 0.8706
# Epoch 13/30
# 125/125 [==============================] - 6s 49ms/step - loss: 0.2676 - categorical_accuracy: 0.9143 - val_loss: 0.4715 - val_categorical_accuracy: 0.8588
# Epoch 14/30
# 125/125 [==============================] - 6s 45ms/step - loss: 0.2420 - categorical_accuracy: 0.9225 - val_loss: 0.4079 - val_categorical_accuracy: 0.8789
# Epoch 15/30
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2435 - categorical_accuracy: 0.9225 - val_loss: 0.4159 - val_categorical_accuracy: 0.8755
# Epoch 16/30
# 125/125 [==============================] - 6s 48ms/step - loss: 0.2095 - categorical_accuracy: 0.9310 - val_loss: 0.3689 - val_categorical_accuracy: 0.8917
# Epoch 17/30
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2004 - categorical_accuracy: 0.9330 - val_loss: 0.4002 - val_categorical_accuracy: 0.8829
# Epoch 18/30
# 125/125 [==============================] - 7s 53ms/step - loss: 0.1806 - categorical_accuracy: 0.9413 - val_loss: 0.3544 - val_categorical_accuracy: 0.9026
# Epoch 19/30
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1651 - categorical_accuracy: 0.9438 - val_loss: 0.4359 - val_categorical_accuracy: 0.8775
# Epoch 20/30
# 125/125 [==============================] - 6s 48ms/step - loss: 0.1670 - categorical_accuracy: 0.9440 - val_loss: 0.3511 - val_categorical_accuracy: 0.9011
# Epoch 21/30
# 125/125 [==============================] - 6s 50ms/step - loss: 0.1479 - categorical_accuracy: 0.9497 - val_loss: 0.3620 - val_categorical_accuracy: 0.9065
# Epoch 22/30
# 125/125 [==============================] - 6s 50ms/step - loss: 0.1320 - categorical_accuracy: 0.9565 - val_loss: 0.3576 - val_categorical_accuracy: 0.9090
# Epoch 23/30
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1223 - categorical_accuracy: 0.9655 - val_loss: 0.3703 - val_categorical_accuracy: 0.8986
# Epoch 24/30
# 125/125 [==============================] - 6s 49ms/step - loss: 0.1202 - categorical_accuracy: 0.9573 - val_loss: 0.3416 - val_categorical_accuracy: 0.9026
# Epoch 25/30
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1146 - categorical_accuracy: 0.9650 - val_loss: 0.3279 - val_categorical_accuracy: 0.9144
# Epoch 26/30
# 125/125 [==============================] - 6s 45ms/step - loss: 0.0997 - categorical_accuracy: 0.9677 - val_loss: 0.3631 - val_categorical_accuracy: 0.9006
# Epoch 27/30
# 125/125 [==============================] - 6s 48ms/step - loss: 0.0989 - categorical_accuracy: 0.9670 - val_loss: 0.3184 - val_categorical_accuracy: 0.9129
# Epoch 28/30
# 125/125 [==============================] - 6s 47ms/step - loss: 0.0821 - categorical_accuracy: 0.9712 - val_loss: 0.3488 - val_categorical_accuracy: 0.9134
# Epoch 29/30
# 125/125 [==============================] - 6s 44ms/step - loss: 0.0825 - categorical_accuracy: 0.9750 - val_loss: 0.3079 - val_categorical_accuracy: 0.9267
# Epoch 30/30
# 125/125 [==============================] - 6s 45ms/step - loss: 0.0698 - categorical_accuracy: 0.9770 - val_loss: 0.3184 - val_categorical_accuracy: 0.9272

# %%
import matplotlib.pyplot as plt

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label='Training losses')
plt.plot(epochs, val_loss, 'b', label='Validation losses')
plt.title('Training and validation loss')
plt.legend()

plt.show()
